# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# plt.rcParams['figure.figsize'] = (9, 6)
# plt.rcParams['figure.dpi'] = 160
# plt.rcParams['figure.facecolor'] = 'w'
# plt.rcParams['figure.edgecolor'] = 'k'
# ax = plt.subplot(111)
plt.figure(num=None, figsize=(9, 6), dpi=160, facecolor='w', edgecolor='k')
plt.xlabel('Square Matrix Dimension N')
plt.ylabel('Gflops/sec')


y = [ 

256, 

512, 

1024, 
     
2048, 
]

x_blas = [

    5.84,
    
17.4,

    
73.6,
    
182,
]


x_best_8 = [
198.829505, 
            
242.280112, 
            
            
254.492418, 
            
235.053284, 
]

x_naive = [
63.750487, 
 
75.459426, 

 
    
76.900479, 
    
38.292436, 
]

x_best_16 = [
             
322.918313, 
    
369.893361, 

    
394.842190, 

371.261916, 
]

x_best_32 = [ 
282.611073, 

401.097204, 
    

    
472.394819, 
    
438.806596, 
 ]

x_best_32_no_min = [ 
                    
296.258264, 
                    
485.178298, 
                    

                    
484.237978, 
                    
469.690363, 
]
x_coalesced = [
198.652695, 

211.466386, 
    

216.575179, 
    
210.620879, 

]

x_C_unroll = [
208.231595, 

219.087167, 
    

226.005750, 
    
214.451094, 
]

x_uncoalesced = [
37.375313, 

38.058117, 

    
38.538543, 

38.616353, 

               ]

plt.semilogx(y, x_best_32_no_min, label="cuda-best (32x32 Thread Blocks/Tiles; Min Removed)")
plt.semilogx(y, x_best_32, label="cuda-best (32x32 Thread Blocks/Tiles)")
plt.semilogx(y, x_best_16, label="cuda-best (16x16 Thread Blocks/Tiles)")
plt.semilogx(y, x_best_8, label="cuda-best (8x8 Thread Blocks/Tiles)")
plt.semilogx(y, x_naive, label="cuda-naive")

# plt.semilogx(y, x_coalesced, label="cuda-coalesced shared memory (32x32 Thread Blocks/Tiles)")

# plt.semilogx(y, x_uncoalesced, label="cuda-uncoalesced shared memory (32x32 Thread Blocks/Tiles)")

# plt.semilogx(y, x_C_unroll, label="cuda-C unrolled (x2 steps) (32x32 Thread Blocks/Tiles)")

# plt.semilogx(y, x_blas, label="blas-multicore")
plt.semilogx(basex=2)

plt.axis([min(y), max(y), 0, max(x_best_32_no_min)+10])
plt.grid(True)
plt.xticks([256,  512, 1024, 2048])
ax = plt.gca()
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)
# plt.show()
plt.savefig('4nBlock.png', bbox_inches='tight')

# %%
import pandas as pd
from collections import OrderedDict

# for i in range (len(y)):
#     data["cuda-best (32x32 Thread Blocks/Tiles; Constant Block Size, 4 elements)"] = x_best_32_no_min
    
  
    
y = [ 

256, 

512, 

1024, 
     
2048, 
]

x_blas = [

    5.84,
    
17.4,

    
73.6,
    
182,
]


x_best_8 = [
198.829505, 
            
242.280112, 
            
            
254.492418, 
            
235.053284, 
]

x_naive = [
63.750487, 
 
75.459426, 

 
    
76.900479, 
    
38.292436, 
]

x_best_16 = [
             
322.918313, 
    
369.893361, 

    
394.842190, 

371.261916, 
]

x_best_32 = [ 
282.611073, 

401.097204, 
    

    
472.394819, 
    
438.806596, 
 ]

x_best_32_no_min = [ 
                    
296.258264, 
                    
485.178298, 
                    

                    
484.237978, 
                    
469.690363, 
]
x_coalesced = [
198.652695, 

211.466386, 
    

216.575179, 
    
210.620879, 

]

x_C_unroll = [
208.231595, 

219.087167, 
    

226.005750, 
    
214.451094, 
]

x_uncoalesced = [
37.375313, 

38.058117, 

    
38.538543, 

38.616353, 

               ]



data = {
"cuda-best (32x32 Thread Blocks/Tiles; Min Removed)": x_best_32_no_min,
"cuda-best (32x32 Thread Blocks/Tiles)": x_best_32,
"cuda-best (16x16 Thread Blocks/Tiles)": x_best_16,
"cuda-best (8x8 Thread Blocks/Tiles)": x_best_8,
"cuda-naive": x_naive}

tuples = [(key, data[key]) for key in data]
data = OrderedDict(tuples)


df = pd.DataFrame(data, index = y)
df.index.rename('N', inplace=True)

writer = pd.ExcelWriter('BlockSizeExperiment.Data.xlsx')
df.to_excel(writer, 'Sheet1')
writer.save()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# plt.rcParams['figure.figsize'] = (9, 6)
# plt.rcParams['figure.dpi'] = 160
# plt.rcParams['figure.facecolor'] = 'w'
# plt.rcParams['figure.edgecolor'] = 'k'
# ax = plt.subplot(111)
plt.figure(num=None, figsize=(9, 6), dpi=160, facecolor='w', edgecolor='k')
plt.xlabel('Square Matrix Dimension N')
plt.ylabel('Gflops/sec')


y = [63, 
64, 
65, 
     
127, 
128, 
129, 
     
255, 
256, 
257, 
     
511, 
512, 
513, 
     
766, 
767, 
768, 
     
1023, 
1024, 
1025, 
     
2047, 
2048, 
2049, 
]

x_blas = [
    0,
    0,
    0,
    
    0,
    0,
    0,
    
    0,
    5.84,
    0,
    
    0,
17.4,
    0,
    
    0,
    0,
 45.3,
    
73.7,
73.6,
73.5,
    
171,
182,
175,]


x_best_8 = [21.208759, 
25.913543, 
21.898493, 
88.331270, 
105.304597, 
88.416225, 
169.009301, 
198.829505, 
158.181280, 
206.656890, 
242.280112, 
195.327677, 
214.416298, 
211.682718, 
246.166655, 
219.104384, 
254.492418, 
210.860291, 
206.659565, 
235.053284, 
203.058286,
]

x_naive = [17.970753, 
19.606127, 
19.157767, 
41.361164, 
44.926161, 
41.837583, 
58.605899, 
63.750487, 
59.064712, 
68.832255, 
75.459426, 
65.266821, 
70.489152, 
69.099246, 
75.872796, 
69.513541, 
76.900479, 
68.300717, 
70.619672, 
38.292436, 
36.378315, ]

x_best_16 = [29.076050, 
32.973808, 
25.204830, 
120.456236, 
133.112788, 
108.336738, 
291.413662, 
322.918313, 
217.079361, 
311.721984, 
369.893361, 
283.464081, 
             
347.263846, 
343.132532, 
386.783130, 
             
350.858478, 
394.842190, 
324.557848, 
             
329.240825, 
371.261916, 
316.099250,
]

x_best_32 = [ 23.602411, 
25.537374, 
15.621628, 
111.412060, 
116.473689, 
83.430933, 
             
266.495488, 
282.611073, 
221.761730, 
             
375.363676, 
401.097204, 
293.780690, 
             
425.288131, 
424.515222, 
447.436446, 
             
448.865657, 
472.394819, 
374.457277, 
             
420.309270, 
438.806596, 
385.351209, ]

x_best_32_no_min = [ 24.464034, 
26.411521, 
16.269219, 
                    
116.479677, 
120.701105, 
87.654461, 
                    
282.042004, 
296.258264, 
235.251795, 
                    
460.201426, 
485.178298, 
310.958229, 
                    
449.945774, 
450.751147, 
475.302723, 
                    
462.404875, 
484.237978, 
387.648832, 
                    
449.923177, 
469.690363, 
414.559485, ]



x_coalesced = [35.193729, 
37.366580, 
29.153651, 
103.900605, 
110.956708, 
90.614062, 
188.917999, 
198.652695, 
128.810174, 
200.394896, 
211.466386, 
169.935533, 
202.271407, 
202.857741, 
213.909276, 
206.040856, 
216.575179, 
189.470917, 
202.472634, 
210.620879, 
194.411061, 

]

x_C_unroll = [37.349471, 
42.658065, 
27.324416, 
115.006238, 
119.870442, 
85.070543, 
201.227746, 
208.231595, 
126.604375, 
213.440827, 
219.087167, 
174.245691, 
212.883236, 
212.695107, 
220.190051, 
219.595662, 
226.005750, 
197.037835, 
207.621740, 
214.451094, 
196.647303, 
]

x_uncoalesced = [10.046201, 
10.576804, 
7.567576, 
22.654030, 
23.333050, 
18.978882, 
36.850366, 
37.375313, 
24.364792, 
37.567675, 
38.058117, 
31.525863, 
37.370881, 
37.517746, 
37.980770, 
38.067136, 
38.538543, 
34.985020, 
38.214162, 
38.616353, 
36.642815, 

               ]

plt.semilogx(y, x_naive, label="cuda-naive")
plt.semilogx(y, x_best_8, label="cuda-best (8x8 Thread Blocks/Tiles)")
plt.semilogx(y, x_best_16, label="cuda-best (16x16 Thread Blocks/Tiles)")
plt.semilogx(y, x_best_32, label="cuda-best (32x32 Thread Blocks/Tiles)")
plt.semilogx(y, x_best_32_no_min, label="cuda-best (32x32 Thread Blocks/Tiles; Min Removed)")
plt.semilogx(y, x_coalesced, label="cuda-coalesced shared memory (32x32 Thread Blocks/Tiles)")

plt.semilogx(y, x_uncoalesced, label="cuda-uncoalesced shared memory (32x32 Thread Blocks/Tiles)")

plt.semilogx(y, x_C_unroll, label="cuda-C unrolled (x2 steps) (32x32 Thread Blocks/Tiles)")

plt.semilogx(y, x_blas, label="blas-multicore")
plt.semilogx(basex=2)

plt.axis([min(y), max(y), 0, max(x_best_32)+50])
plt.grid(True)
plt.xticks([64, 128, 256,  512, 1024, 2048])
ax = plt.gca()
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)
plt.show()
# plt.savefig('20n.png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# plt.rcParams['figure.figsize'] = (9, 6)
# plt.rcParams['figure.dpi'] = 160
# plt.rcParams['figure.facecolor'] = 'w'
# plt.rcParams['figure.edgecolor'] = 'k'
# ax = plt.subplot(111)
plt.figure(num=None, figsize=(9, 6), dpi=160, facecolor='w', edgecolor='k')
plt.xlabel('Square Matrix Dimension N')
plt.ylabel('Gflops/sec')


y = [63,
 64,
 65,
 95,
 96,
 97,
 127,
 128,
 129,
 159,
 160,
 161,
 191,
 192,
 193,
 223,
 224,
 225,
 255,
 256,
 257,
 287,
 288,
 289,
 319,
 320,
 321,
 351,
 352,
 353,
 383,
 384,
 385,
 415,
 416,
 417,
 447,
 448,
 449,
 479,
 480,
 481,
 511,
 512,
 513,
 543,
 544,
 545,
 575,
 576,
 577,
 607,
 608,
 609,
 639,
 640,
 641,
 671,
 672,
 673,
 703,
 704,
 705,
 735,
 736,
 737,
 767,
 768,
 769,
 799,
 800,
 801,
 831,
 832,
 833,
 863,
 864,
 865,
 895,
 896,
 897,
 927,
 928,
 929,
 959,
 960,
 961,
 991,
 992,
 993,
 1023,
 1024,
 1025,
 1055,
 1056,
 1057,
 1087,
 1088,
 1089,
 1119,
 1120,
 1121,
 1151,
 1152,
 1153,
 1183,
 1184,
 1185,
 1215,
 1216,
 1217,
 1247,
 1248,
 1249,
 1279,
 1280,
 1281,
 1311,
 1312,
 1313,
 1343,
 1344,
 1345,
 1375,
 1376,
 1377,
 1407,
 1408,
 1409,
 1439,
 1440,
 1441,
 1471,
 1472,
 1473,
 1503,
 1504,
 1505,
 1535,
 1536,
 1537,
 1567,
 1568,
 1569,
 1599,
 1600,
 1601,
 1631,
 1632,
 1633,
 1663,
 1664,
 1665,
 1695,
 1696,
 1697,
 1727,
 1728,
 1729,
 1759,
 1760,
 1761,
 1791,
 1792,
 1793,
 1823,
 1824,
 1825,
 1855,
 1856,
 1857,
 1887,
 1888,
 1889,
 1919,
 1920,
 1921,
 1951,
 1952,
 1953,
 1983,
 1984,
 1985,
 2015,
 2016,
 2017,
 2047,
 2048,
 2049]


x_blas = [
5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 73.7, 73.6, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 171, 182, 175    

         ]


x_best_8 = [
21.116946, 26.213175, 22.085337, 50.642042, 60.724133, 52.618942, 88.673145, 105.887721, 89.094263, 132.093514, 156.84365, 124.185947, 154.431394, 185.745747, 140.41347, 163.381275, 198.95991, 142.160098, 169.293171, 199.18407, 158.478805, 176.655038, 217.331317, 165.700144, 188.337025, 222.964972, 171.126594, 191.508348, 224.630537, 181.44913, 198.164972, 235.223429, 180.653293, 196.8695, 234.331242, 190.099956, 206.092722, 243.616983, 189.614203, 206.007955, 240.961895, 198.34386, 207.119595, 242.263951, 195.630671, 209.989003, 248.751185, 204.856492, 208.422218, 246.630813, 201.119247, 217.756158, 244.947781, 200.957936, 216.153927, 254.170626, 200.254452, 212.682831, 251.375729, 210.229507, 211.404149, 249.664554, 208.744536, 213.644303, 248.301835, 208.548148, 213.964768, 248.689259, 208.265314, 212.913139, 247.460831, 206.462187, 211.871903, 247.655526, 206.058186, 210.951942, 245.984954, 203.93258, 209.832677, 244.598185, 203.815306, 209.274171, 243.340785, 203.986781, 209.807518, 241.770169, 203.984004, 209.87284, 241.468936, 202.364298, 211.925147, 244.024135, 204.458983, 208.985481, 240.220967, 203.466757, 208.78694, 238.366749, 203.339291, 209.159882, 239.00323, 203.364326, 209.864177, 238.86213, 203.712129, 209.236119, 237.774796, 203.278555, 210.880599, 239.332237, 205.766233, 211.326056, 238.542509, 205.41715, 212.392529, 238.89599, 207.090602, 212.067548, 238.717238, 206.327004, 211.034512, 238.209028, 206.177494, 210.772107, 239.636981, 205.640454, 209.663197, 239.797132, 203.865185, 208.795937, 240.296654, 204.641954, 209.852504, 241.708824, 204.649209, 209.454208, 241.511566, 204.370836, 209.227167, 240.35441, 204.204551, 209.170184, 237.219318, 204.339669, 209.263451, 237.264073, 204.377873, 209.113813, 236.922495, 204.354821, 209.1818, 237.390784, 204.665008, 209.237568, 237.021851, 204.786741, 209.269754, 236.994113, 204.944909, 209.346884, 237.196786, 205.04446, 209.523361, 237.311477, 205.33718, 209.719155, 237.255334, 205.337991, 209.571366, 237.240366, 205.096982, 209.34316, 237.070048, 205.256706, 209.666537, 237.30076, 205.491671, 209.643725, 237.111979, 205.72711, 209.383039, 237.164504, 205.595047, 209.648904, 237.347145, 206.027925, 209.822206, 237.892346, 205.861617]
# x_best_8 = x_best_8[:93] + x_best_8[96:] 


x_interleave_sync = [
    38.444763, 41.0189, 32.593682, 99.808254, 104.693236, 54.117877, 115.594228, 120.354286, 102.322476, 185.884848, 196.262857, 115.602874, 188.423128, 195.984908, 131.753432, 199.092628, 206.51215, 147.756986, 211.133356, 218.465234, 146.648959, 197.352666, 205.585245, 161.785164, 213.7819, 222.172035, 163.88543, 210.651954, 218.028363, 168.001233, 210.971815, 217.877877, 172.683429, 213.368823, 219.992045, 177.677133, 215.608143, 222.943588, 182.742738, 218.795816, 224.609339, 186.471929, 222.423175, 229.793781, 187.779261, 220.705111, 227.978317, 192.287784, 224.288673, 231.571095, 193.337413, 224.700121, 232.727695, 194.571662, 222.690957, 233.00563, 199.458981, 225.86429, 232.61829, 198.692674, 223.697497, 231.406588, 197.771997, 222.255675, 228.740152, 197.800005, 222.667959, 227.901975, 197.842889, 221.14956, 228.129409, 199.259256, 220.222701, 226.31072, 198.320304, 219.398528, 226.143486, 198.611272, 218.134781, 227.006794, 198.543178, 217.138003, 226.341413, 199.334722, 218.068901, 225.636981, 200.533878, 218.085427, 225.311806, 200.339558, 217.533577, 224.897061, 200.273693, 218.262708, 223.350186, 200.565742, 217.794449, 224.402526, 201.451951, 217.565589, 224.381178, 201.72463, 217.345171, 223.743837, 202.252984, 218.327288, 224.332554, 203.461727, 217.863064, 224.519259, 200.551806, 216.268309, 223.777898, 201.00273, 216.465027, 223.831605, 202.520036, 217.8896, 223.17806, 203.277587, 217.322412, 223.517757, 204.027115, 217.775084, 224.044559, 203.732991, 216.93728, 224.647605, 203.426136, 217.452404, 223.7583, 203.832709, 218.071755, 223.552719, 205.511099, 217.217969, 222.730036, 205.648745, 217.84119, 223.407992, 205.018755, 216.898016, 223.431807, 202.49888, 214.442784, 223.675535, 204.40882, 216.707012, 221.855091, 205.670912, 217.774896, 222.614958, 204.930104, 216.622671, 222.761875, 204.931831, 217.44469, 221.332955, 204.910341, 217.213584, 223.517578, 206.22932, 217.588013, 223.71135, 206.443975, 217.491804, 222.367286, 207.542322, 217.645297, 223.587276, 206.747625, 216.753855, 224.228558, 204.4386, 216.094898, 224.081335, 204.063832, 213.768456, 222.624281, 205.517973, 215.234186, 221.571771, 206.122976, 215.439515, 221.933541, 206.305412, 216.919136, 223.274812, 206.41143
]


x_naive = [
18.21261, 19.972963, 19.20408, 42.635502, 46.589476, 38.861256, 41.880333, 45.969809, 43.075547, 64.953887, 70.603169, 44.412892, 63.149708, 62.586176, 51.801868, 66.046639, 72.02463, 56.020572, 59.072578, 65.486101, 59.412938, 63.534529, 68.875841, 59.341931, 68.774096, 74.478529, 60.624582, 66.531166, 72.411598, 64.260488, 66.65825, 72.356787, 65.997406, 66.020092, 72.29386, 65.553228, 67.369111, 73.799153, 65.657567, 68.403106, 75.1128, 65.516103, 69.795263, 76.711856, 66.166002, 68.738378, 75.371389, 66.824188, 68.313397, 74.906207, 66.55097, 70.170411, 77.15384, 67.039805, 68.64668, 75.344856, 67.288276, 70.344763, 77.494959, 67.495888, 69.716545, 76.598962, 67.67797, 69.060369, 76.06152, 67.849459, 69.99047, 76.793548, 67.992451, 70.01193, 76.982632, 68.219497, 70.053972, 77.375361, 68.000596, 70.057891, 77.367129, 68.22034, 69.092276, 76.131014, 68.53211, 69.74319, 76.822989, 68.480311, 70.298047, 77.276746, 68.571547, 70.6607, 77.672901, 68.783532, 70.209163, 77.503458, 68.919543, 70.649524, 77.736268, 68.988369, 70.438488, 76.613222, 68.397373, 70.407292, 77.634569, 69.059564, 70.518604, 77.551315, 69.031081, 70.629821, 77.638271, 69.189884, 70.435438, 77.55912, 69.2025, 70.732892, 77.520347, 69.403702, 70.593191, 77.736099, 69.364077, 70.661863, 77.651723, 69.484046, 70.720958, 77.674741, 69.492902, 70.622702, 77.642031, 69.296485, 70.948556, 77.974326, 69.703835, 70.819952, 77.860774, 69.715735, 70.94865, 78.040591, 69.778384, 70.84092, 77.968062, 69.754377, 70.920318, 78.056195, 69.896415, 70.969015, 78.059204, 69.852064, 71.013497, 78.004954, 69.864909, 70.897925, 77.899087, 70.018853, 70.94243, 77.912421, 69.837576, 70.911082, 77.339339, 69.776765, 70.506402, 76.99673, 69.898793, 70.679341, 76.501499, 69.785086, 70.251505, 76.867978, 69.602601, 70.366758, 77.372595, 69.945319, 70.702305, 77.53441, 70.049465, 70.446734, 77.198508, 69.650618, 70.445341, 77.148584, 70.051943, 70.727469, 77.467419, 70.017249, 70.697537, 77.604987, 70.096389, 70.612307, 76.982335, 70.014123, 70.918778, 77.404322, 70.468481]

x_best_16 = [
    29.177163, 33.328634, 25.416168, 73.061589, 82.071254, 58.595255, 119.509543, 132.103222, 107.708191, 190.097595, 210.421571, 145.20726, 235.006185, 257.944339, 174.239927, 270.314495, 284.937962, 203.643332, 288.368726, 319.053044, 213.035917, 283.573636, 316.455567, 241.424846, 315.132299, 350.739313, 237.012095, 296.626297, 336.205782, 247.215899, 307.466566, 342.796434, 249.417523, 306.65316, 363.280594, 267.053165, 324.940631, 354.381214, 266.102849, 311.633366, 357.070857, 262.451216, 306.136794, 364.069634, 279.047101, 327.218307, 376.0418, 273.6539, 311.101514, 354.54468, 280.04989, 320.475145, 354.650147, 296.766973, 335.175278, 383.360893, 290.06202, 324.485093, 363.842273, 300.891687, 337.34424, 380.795881, 298.493136, 331.152621, 371.717969, 302.300524, 337.360299, 380.946251, 300.42116, 329.86865, 374.412751, 303.22402, 332.065777, 376.874647, 303.147292, 331.228664, 372.765945, 302.595207, 329.644509, 374.562521, 300.800892, 325.90684, 370.151206, 300.896783, 327.265404, 370.130608, 300.081762, 324.322126, 363.507248, 300.492407, 325.146184, 366.104343, 299.427779, 323.061568, 364.018001, 299.239492, 321.748135, 361.125703, 301.312581, 323.297535, 360.212087, 301.850917, 323.076003, 364.066776, 300.821702, 322.858476, 359.234043, 301.275496, 323.66728, 361.10442, 302.333266, 321.557769, 360.25466, 303.109779, 322.779258, 359.793281, 303.336843, 322.818869, 359.548532, 304.574001, 321.403042, 359.80444, 305.146651, 322.939654, 360.050705, 305.106771, 323.688192, 361.205483, 306.557705, 324.173548, 360.847477, 307.73024, 323.158399, 360.93164, 307.066621, 323.681169, 361.802874, 308.368466, 324.063536, 361.34234, 309.604643, 324.182803, 361.989102, 309.741143, 324.852562, 362.167142, 310.133488, 325.053348, 362.20845, 310.895656, 325.800117, 362.269905, 311.434038, 326.198759, 362.260258, 311.655704, 325.948224, 362.108764, 311.710435, 326.062125, 362.771766, 312.288997, 327.490349, 362.763892, 313.251012, 326.501901, 363.226865, 313.721669, 327.123385, 363.801728, 313.936523, 327.395223, 363.141345, 314.253566, 327.11617, 363.226519, 314.416531, 326.372508, 363.544769, 314.818552, 326.899939, 363.348457, 314.863062, 327.408273, 363.620625, 316.021449, 329.172924, 364.861361, 316.932366
]

x_best_32 = [ 
23.337186, 25.478198, 15.581478, 47.963873, 50.357603, 50.421865, 110.694338, 116.219766, 83.415474, 154.485323, 160.155395, 159.744551, 262.841705, 272.118923, 122.396909, 184.458341, 192.01092, 188.930278, 266.260825, 282.633775, 221.599525, 306.098448, 321.982798, 312.803146, 413.365977, 434.706414, 241.60828, 313.985041, 327.21219, 315.567145, 396.050175, 415.534366, 273.334331, 340.666105, 356.870379, 344.940959, 418.454119, 437.523914, 261.256775, 313.953231, 341.260382, 318.027911, 375.275582, 400.637628, 294.223366, 344.996767, 359.274031, 348.066533, 400.251237, 421.075181, 326.503577, 377.017611, 396.237165, 379.808637, 434.105874, 457.139376, 328.928551, 374.563511, 392.181812, 376.7529, 425.228679, 447.534798, 335.210858, 378.799512, 395.472938, 381.098375, 425.568612, 446.887087, 343.836662, 382.393614, 411.27282, 384.934534, 424.613006, 454.021283, 347.861256, 383.812327, 404.900777, 386.524663, 424.414965, 449.081523, 354.617935, 387.531452, 404.164468, 390.027067, 425.737279, 446.566797, 358.981133, 390.243697, 408.591044, 392.58605, 427.103657, 445.707004, 352.434151, 382.521525, 401.35849, 383.825143, 412.515032, 436.500291, 352.697152, 381.689282, 398.469544, 382.876037, 411.184298, 432.189752, 359.941838, 385.523837, 405.881003, 386.032061, 415.575047, 436.182789, 358.010038, 381.741584, 399.015731, 385.605395, 410.853088, 429.527245, 362.319227, 386.211837, 405.98101, 389.171853, 413.586292, 434.536442, 361.629925, 384.940797, 404.779661, 386.361569, 409.812137, 429.31435, 361.158005, 384.644707, 404.417178, 383.697728, 409.085707, 430.428062, 362.522874, 383.234646, 404.288107, 384.729444, 407.015137, 429.455227, 364.725697, 387.139608, 408.797799, 386.262457, 409.615468, 429.233824, 366.005019, 387.544093, 405.682736, 388.208107, 410.431504, 429.180052, 367.92408, 388.249279, 407.793732, 388.000882, 408.677914, 429.041535, 369.863163, 388.242923, 407.397119, 389.566253, 408.23952, 427.155312, 370.806623, 389.918992, 406.734417, 390.171392, 405.778695, 427.323626, 371.767413, 389.366718, 409.289987, 390.959285, 407.974773, 429.242302, 373.215049, 390.633985, 409.238731, 391.324436, 407.445865, 428.571085, 374.145307, 391.998578, 409.200395, 392.682511, 407.601969, 427.889582, 375.964388
]

x_best_32_no_min = [ 

17.802973, 26.735845, 16.494032, 50.595728, 52.883736, 36.549654, 80.48659, 120.659712, 88.143576, 162.738955, 168.215697, 114.054924, 187.890123, 284.370075, 193.617944, 216.697408, 227.314227, 178.664363, 221.276893, 294.985304, 234.945149, 323.590359, 340.914262, 258.266077, 343.04049, 458.320812, 252.163395, 286.143893, 303.255414, 258.063495, 307.627122, 354.31606, 299.200947, 373.570594, 391.724999, 311.844976, 371.385342, 466.522951, 315.352216, 384.198599, 387.105133, 326.735744, 367.587746, 482.928672, 355.867719, 390.933807, 410.959681, 343.662155, 381.167875, 432.447701, 354.679727, 412.746035, 432.297461, 371.084552, 405.208078, 481.785514, 370.546019, 415.594057, 439.81263, 379.669645, 421.011092, 471.326515, 387.465943, 420.266428, 441.156656, 391.279098, 426.089356, 469.592234, 404.052299, 430.885368, 456.555884, 396.155379, 427.655661, 477.049704, 406.487733, 427.956867, 454.56142, 402.355319, 436.834424, 488.806823, 407.026069, 432.348504, 453.741083, 403.045031, 431.313675, 481.131494, 406.092848, 431.272723, 455.562834, 403.12112, 430.390024, 481.883324, 404.519914, 424.908522, 450.855832, 405.149582, 430.268817, 478.225436, 405.956634, 425.978358, 446.766265, 405.69026, 430.22114, 467.459463, 404.949489, 426.834668, 448.759464, 403.651924, 427.986821, 471.405817, 406.788881, 423.358492, 447.709652, 408.534303, 428.5973, 467.890728, 409.906641, 426.131119, 448.675804, 409.679449, 430.0128, 470.911887, 411.543296, 427.388815, 447.573207, 411.960299, 430.185341, 465.043387, 411.005633, 425.335968, 446.74171, 413.363093, 430.93727, 468.158667, 413.261665, 425.471519, 447.626954, 413.697399, 431.883927, 463.945525, 416.057747, 427.737783, 448.28564, 416.782794, 433.205768, 466.541146, 416.611841, 430.124123, 452.350498, 416.835852, 431.14451, 466.987207, 414.125935, 425.847913, 451.08046, 413.715744, 427.996227, 467.123862, 413.021693, 426.551372, 451.03603, 414.915329, 429.383898, 465.589602, 414.929109, 426.055078, 450.581827, 414.829057, 428.666487, 466.016002, 413.071444, 426.69764, 449.887418, 414.049636, 430.062638, 464.023408, 414.981537, 427.694874, 451.417383, 414.658565, 430.391926, 466.493876, 414.65354, 427.082546, 451.782203, 415.142569, 430.249766, 464.98106, 415.343802
]



x_coalesced = [
34.630118, 36.613774, 28.514933, 87.220262, 90.652296, 48.187664, 102.985208, 109.629127, 88.944643, 163.069501, 172.505966, 102.48849, 167.298467, 177.081416, 115.748606, 174.831383, 186.947281, 127.5823, 184.772187, 195.140789, 126.638154, 174.477489, 183.838675, 144.987329, 191.847944, 201.056128, 146.383681, 188.473571, 199.320364, 149.551942, 187.786519, 199.211951, 155.817757, 189.760672, 199.717826, 158.227484, 192.640062, 203.306472, 162.173847, 195.031341, 204.987723, 166.029639, 197.654545, 208.757837, 167.914567, 197.222431, 208.111835, 169.007492, 196.676458, 207.885732, 172.46806, 201.339972, 211.843918, 172.061873, 197.035324, 208.634597, 175.053961, 199.611277, 210.663085, 175.354457, 198.102414, 208.589889, 174.883863, 195.423517, 205.913794, 175.208883, 194.393588, 205.52753, 173.168389, 193.343769, 204.416929, 173.285842, 192.415492, 203.277347, 173.547018, 191.26759, 202.385336, 173.644724, 190.308136, 202.046537, 174.141592, 190.871172, 201.876308, 175.17873, 191.551943, 201.847747, 175.197396, 190.546949, 200.438472, 175.171531, 190.962545, 200.266347, 175.864243, 190.514414, 200.990382, 176.305633, 191.074215, 200.329375, 176.496104, 190.430686, 200.445136, 177.13947, 190.734363, 200.08137, 177.191629, 190.489131, 200.274082, 177.322024, 190.068958, 199.967393, 177.623085, 190.181114, 200.012347, 177.852454, 190.091788, 199.994271, 178.134225, 190.179527, 200.208275, 178.365005, 190.085437, 199.905514, 178.628797, 188.464754, 197.468608, 178.753579, 189.948192, 199.321297, 179.149612, 190.060994, 199.162388, 179.28826, 190.062396, 199.595118, 179.62731, 190.167336, 200.368522, 179.750661, 190.097753, 199.580487, 179.963887, 189.959919, 199.818039, 179.911253, 189.950691, 199.123677, 180.27631, 189.864952, 199.184017, 180.320798, 189.900297, 198.851881, 180.498296, 189.894181, 198.420318, 180.767732, 189.935811, 195.674399, 180.952593, 189.642961, 197.741081, 180.971003, 189.339613, 198.398494, 181.189869, 189.741555, 198.559402, 181.501118, 190.056976, 198.761528, 181.369958, 189.853562, 199.01846, 181.665917, 189.694732, 198.749531, 181.625398, 189.054736, 198.731721, 181.734351, 189.248206, 198.172943, 181.617015, 189.393939, 196.782049, 182.057531, 189.85255, 198.347457, 182.191317
]

x_C_unroll = [
39.756373, 42.419430, 26.988302, 82.916564, 87.293619, 52.924485, 113.931057, 118.346358, 83.858305, 154.783160, 160.943081, 112.093812, 183.853606, 190.728005, 111.700867, 169.994391, 176.609763, 141.719425, 201.192818, 207.779680, 124.983066, 169.735928, 176.450486, 153.351412, 202.764726, 209.066016, 143.044996, 184.703102, 191.055899, 158.563310, 199.648320, 206.770485, 158.844986, 190.974978, 198.470738, 167.815931, 204.021850, 211.267461, 162.396170, 195.173786, 201.944961, 177.443514, 210.691153, 217.252859, 167.876982, 197.146870, 203.831462, 182.839275, 212.873006, 219.984707, 174.862067, 202.818986, 210.060739, 182.768810, 208.447833, 220.414127, 180.060023, 204.795791, 211.323254, 185.491591, 210.615380, 218.081159, 179.601158, 201.974847, 207.624704, 186.154236, 208.267453, 215.985710, 179.458016, 199.823441, 206.994955, 187.170871, 207.079753, 214.786363, 180.427584, 198.943136, 205.265692, 186.077246, 205.569817, 212.219724, 180.438311, 198.278792, 205.080118, 188.496456, 204.628926, 211.546942, 183.380465, 199.763193, 206.079329, 188.296189, 204.547425, 211.282901, 185.113396, 199.257498, 206.541417, 189.668228, 204.737191, 211.242460, 185.264926, 200.126003, 206.889577, 190.665472, 205.610556, 212.084194, 186.881270, 201.711356, 208.090113, 192.730102, 206.164348, 211.821634, 189.519136, 202.341700, 208.803908, 194.021951, 207.259662, 214.084655, 190.966733, 203.730438, 209.974165, 195.493248, 208.537125, 214.870717, 192.184670, 205.040453, 210.737560, 197.038262, 209.584078, 216.311230, 193.907490, 205.665602, 211.626332, 197.253817, 209.936653, 216.326948, 195.002850, 205.866137, 212.786898, 199.080513, 209.819006, 216.361688, 195.858200, 206.332494, 212.580363, 200.031125, 210.348320, 217.558156, 196.847920, 207.002341, 213.416170, 200.513364, 210.993590, 217.325908, 196.986606, 207.713842, 213.891296, 200.703835, 211.439534, 212.801567, 191.707165, 198.604836, 203.199133, 190.617863, 199.932615, 206.075198, 187.713008, 198.869621, 206.794498, 198.201198, 207.435803, 213.876837, 198.982330, 208.345712, 214.731710, 202.707888, 212.149439, 218.622051, 199.855799, 209.045445, 215.601388, 203.104002, 212.135709, 218.695218, 200.277613, 208.988023, 215.643623, 203.351765, 212.055715, 215.875129, 199.507167, 
]

x_uncoalesced = [
10.072735, 10.60895, 7.58302, 23.52847, 24.363009, 10.187699, 22.668974, 23.339241, 19.007328, 35.476298, 36.397642, 19.893519, 30.810898, 31.313223, 23.141548, 35.492301, 36.194249, 25.438, 37.028121, 37.47673, 24.441619, 33.829048, 34.362154, 27.269013, 36.549479, 37.11998, 27.331835, 35.574537, 36.097917, 27.854929, 35.461651, 36.007531, 29.803616, 36.859045, 36.55475, 29.580022, 36.342501, 36.788532, 30.515226, 37.039155, 37.586162, 31.424088, 37.604769, 38.06612, 31.535906, 37.338629, 37.820766, 31.618769, 37.105047, 37.559554, 32.576281, 37.874306, 38.32979, 32.204052, 37.169636, 37.666937, 33.197653, 38.031346, 38.534362, 33.143462, 37.776189, 38.211649, 33.092253, 37.488368, 37.953666, 33.449303, 37.406118, 38.054632, 33.886104, 37.996662, 38.399923, 34.095232, 38.014673, 38.460974, 34.215747, 38.001899, 38.520289, 34.18105, 37.777678, 38.176125, 34.355594, 37.874748, 38.3461, 34.521559, 37.924183, 38.394634, 34.643802, 37.960182, 38.441301, 34.762623, 37.980052, 38.437387, 34.866762, 37.971938, 38.394191, 34.958469, 38.04767, 38.444421, 35.052699, 38.01773, 38.441672, 35.120931, 37.984476, 38.470418, 35.183936, 37.969042, 38.392435, 35.359588, 38.08969, 38.471877, 35.424326, 38.077024, 38.491056, 35.508953, 38.113254, 38.477153, 35.490649, 38.015928, 38.461595, 35.600651, 38.031259, 38.440929, 35.67438, 38.086496, 38.486234, 35.762342, 38.130148, 38.491124, 35.76187, 38.068452, 38.469739, 35.847071, 38.10915, 38.466299, 35.926978, 38.145219, 38.487078, 35.974733, 38.155216, 38.514222, 35.978496, 38.099574, 38.471659, 36.009095, 38.087342, 38.449079, 36.121975, 38.170544, 38.48528, 36.153642, 38.164545, 38.49233, 36.196942, 38.166116, 38.479594, 36.183506, 38.116489, 38.479656, 36.229673, 38.148349, 38.474755, 36.298646, 38.164412, 38.482503, 36.330052, 38.159423, 38.47674, 36.343503, 38.143744, 38.477283, 36.380136, 38.155163, 38.45813, 36.435071, 38.18089, 38.484443, 36.453946, 38.164893, 38.477921, 36.466198, 38.14692, 38.47814, 36.472734, 38.139969, 38.445886, 36.515453, 38.13987, 38.461557, 36.552029
               ]


# print(len(x_interleave_sync))
# print (len(x_naive))
# print (len(x_best_16))
# print (len(x_best_32))
# print (len(x_best_32_no_min))
# print (len(x_coalesced))
# print (len(x_C_unroll))
# print (len(x_uncoalesced))


# plt.semilogx(y, x_best_32_no_min, label="cuda-best (32x32 Thread Blocks/Tiles; Min Removed)")
plt.semilogx(y, x_best_32_no_min, label="cuda-best (32x32 Thread Blocks/Tiles; Constant Block Size, 4 elements)")
plt.semilogx(y, x_best_32, label="cuda-best (32x32 Thread Blocks/Tiles; 4 elements)")
plt.semilogx(y, x_best_16, label="cuda-best (16x16 Thread Blocks/Tiles; 4 elements)")
plt.semilogx(y, x_best_8, label="cuda-best (8x8 Thread Blocks/Tiles; 4 elements)")
plt.semilogx(y, x_interleave_sync, label="cuda-interleaved __syncthreads (32x32 Thread Blocks/Tiles; 1 element)")
plt.semilogx(y, x_C_unroll, label="cuda-C unrolled (x2 steps) (32x32 Thread Blocks/Tiles; 1 element)")
plt.semilogx(y, x_coalesced, label="cuda-coalesced shared memory (32x32 Thread Blocks/Tiles; 1 element)")
plt.semilogx(y, x_naive, label="cuda-naive")
plt.semilogx(y, x_uncoalesced, label="cuda-uncoalesced shared memory (32x32 Thread Blocks/Tiles; 1 element)")
plt.semilogx(y, x_blas, label="blas-multicore")
plt.semilogx(basex=2)

plt.axis([min(y), max(y), 0, max(x_best_32_no_min)+10])
plt.grid(True)
plt.xticks([64, 128, 256,  512, 1024, 2048])
ax = plt.gca()
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)
plt.show()
# plt.savefig('20n.png', bbox_inches='tight')

# %%
import pandas as pd
from collections import OrderedDict

# for i in range (len(y)):
#     data["cuda-best (32x32 Thread Blocks/Tiles; Constant Block Size, 4 elements)"] = x_best_32_no_min
    
  
    

y = [63,
 64,
 65,
 95,
 96,
 97,
 127,
 128,
 129,
 159,
 160,
 161,
 191,
 192,
 193,
 223,
 224,
 225,
 255,
 256,
 257,
 287,
 288,
 289,
 319,
 320,
 321,
 351,
 352,
 353,
 383,
 384,
 385,
 415,
 416,
 417,
 447,
 448,
 449,
 479,
 480,
 481,
 511,
 512,
 513,
 543,
 544,
 545,
 575,
 576,
 577,
 607,
 608,
 609,
 639,
 640,
 641,
 671,
 672,
 673,
 703,
 704,
 705,
 735,
 736,
 737,
 767,
 768,
 769,
 799,
 800,
 801,
 831,
 832,
 833,
 863,
 864,
 865,
 895,
 896,
 897,
 927,
 928,
 929,
 959,
 960,
 961,
 991,
 992,
 993,
 1023,
 1024,
 1025,
 1055,
 1056,
 1057,
 1087,
 1088,
 1089,
 1119,
 1120,
 1121,
 1151,
 1152,
 1153,
 1183,
 1184,
 1185,
 1215,
 1216,
 1217,
 1247,
 1248,
 1249,
 1279,
 1280,
 1281,
 1311,
 1312,
 1313,
 1343,
 1344,
 1345,
 1375,
 1376,
 1377,
 1407,
 1408,
 1409,
 1439,
 1440,
 1441,
 1471,
 1472,
 1473,
 1503,
 1504,
 1505,
 1535,
 1536,
 1537,
 1567,
 1568,
 1569,
 1599,
 1600,
 1601,
 1631,
 1632,
 1633,
 1663,
 1664,
 1665,
 1695,
 1696,
 1697,
 1727,
 1728,
 1729,
 1759,
 1760,
 1761,
 1791,
 1792,
 1793,
 1823,
 1824,
 1825,
 1855,
 1856,
 1857,
 1887,
 1888,
 1889,
 1919,
 1920,
 1921,
 1951,
 1952,
 1953,
 1983,
 1984,
 1985,
 2015,
 2016,
 2017,
 2047,
 2048,
 2049]


x_blas = [
5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 5.84, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 45.3, 73.7, 73.6, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 73.5, 171, 182, 175    

         ]


x_best_8 = [
21.116946, 26.213175, 22.085337, 50.642042, 60.724133, 52.618942, 88.673145, 105.887721, 89.094263, 132.093514, 156.84365, 124.185947, 154.431394, 185.745747, 140.41347, 163.381275, 198.95991, 142.160098, 169.293171, 199.18407, 158.478805, 176.655038, 217.331317, 165.700144, 188.337025, 222.964972, 171.126594, 191.508348, 224.630537, 181.44913, 198.164972, 235.223429, 180.653293, 196.8695, 234.331242, 190.099956, 206.092722, 243.616983, 189.614203, 206.007955, 240.961895, 198.34386, 207.119595, 242.263951, 195.630671, 209.989003, 248.751185, 204.856492, 208.422218, 246.630813, 201.119247, 217.756158, 244.947781, 200.957936, 216.153927, 254.170626, 200.254452, 212.682831, 251.375729, 210.229507, 211.404149, 249.664554, 208.744536, 213.644303, 248.301835, 208.548148, 213.964768, 248.689259, 208.265314, 212.913139, 247.460831, 206.462187, 211.871903, 247.655526, 206.058186, 210.951942, 245.984954, 203.93258, 209.832677, 244.598185, 203.815306, 209.274171, 243.340785, 203.986781, 209.807518, 241.770169, 203.984004, 209.87284, 241.468936, 202.364298, 211.925147, 244.024135, 204.458983, 208.985481, 240.220967, 203.466757, 208.78694, 238.366749, 203.339291, 209.159882, 239.00323, 203.364326, 209.864177, 238.86213, 203.712129, 209.236119, 237.774796, 203.278555, 210.880599, 239.332237, 205.766233, 211.326056, 238.542509, 205.41715, 212.392529, 238.89599, 207.090602, 212.067548, 238.717238, 206.327004, 211.034512, 238.209028, 206.177494, 210.772107, 239.636981, 205.640454, 209.663197, 239.797132, 203.865185, 208.795937, 240.296654, 204.641954, 209.852504, 241.708824, 204.649209, 209.454208, 241.511566, 204.370836, 209.227167, 240.35441, 204.204551, 209.170184, 237.219318, 204.339669, 209.263451, 237.264073, 204.377873, 209.113813, 236.922495, 204.354821, 209.1818, 237.390784, 204.665008, 209.237568, 237.021851, 204.786741, 209.269754, 236.994113, 204.944909, 209.346884, 237.196786, 205.04446, 209.523361, 237.311477, 205.33718, 209.719155, 237.255334, 205.337991, 209.571366, 237.240366, 205.096982, 209.34316, 237.070048, 205.256706, 209.666537, 237.30076, 205.491671, 209.643725, 237.111979, 205.72711, 209.383039, 237.164504, 205.595047, 209.648904, 237.347145, 206.027925, 209.822206, 237.892346, 205.861617]
# x_best_8 = x_best_8[:93] + x_best_8[96:] 


x_interleave_sync = [
    38.444763, 41.0189, 32.593682, 99.808254, 104.693236, 54.117877, 115.594228, 120.354286, 102.322476, 185.884848, 196.262857, 115.602874, 188.423128, 195.984908, 131.753432, 199.092628, 206.51215, 147.756986, 211.133356, 218.465234, 146.648959, 197.352666, 205.585245, 161.785164, 213.7819, 222.172035, 163.88543, 210.651954, 218.028363, 168.001233, 210.971815, 217.877877, 172.683429, 213.368823, 219.992045, 177.677133, 215.608143, 222.943588, 182.742738, 218.795816, 224.609339, 186.471929, 222.423175, 229.793781, 187.779261, 220.705111, 227.978317, 192.287784, 224.288673, 231.571095, 193.337413, 224.700121, 232.727695, 194.571662, 222.690957, 233.00563, 199.458981, 225.86429, 232.61829, 198.692674, 223.697497, 231.406588, 197.771997, 222.255675, 228.740152, 197.800005, 222.667959, 227.901975, 197.842889, 221.14956, 228.129409, 199.259256, 220.222701, 226.31072, 198.320304, 219.398528, 226.143486, 198.611272, 218.134781, 227.006794, 198.543178, 217.138003, 226.341413, 199.334722, 218.068901, 225.636981, 200.533878, 218.085427, 225.311806, 200.339558, 217.533577, 224.897061, 200.273693, 218.262708, 223.350186, 200.565742, 217.794449, 224.402526, 201.451951, 217.565589, 224.381178, 201.72463, 217.345171, 223.743837, 202.252984, 218.327288, 224.332554, 203.461727, 217.863064, 224.519259, 200.551806, 216.268309, 223.777898, 201.00273, 216.465027, 223.831605, 202.520036, 217.8896, 223.17806, 203.277587, 217.322412, 223.517757, 204.027115, 217.775084, 224.044559, 203.732991, 216.93728, 224.647605, 203.426136, 217.452404, 223.7583, 203.832709, 218.071755, 223.552719, 205.511099, 217.217969, 222.730036, 205.648745, 217.84119, 223.407992, 205.018755, 216.898016, 223.431807, 202.49888, 214.442784, 223.675535, 204.40882, 216.707012, 221.855091, 205.670912, 217.774896, 222.614958, 204.930104, 216.622671, 222.761875, 204.931831, 217.44469, 221.332955, 204.910341, 217.213584, 223.517578, 206.22932, 217.588013, 223.71135, 206.443975, 217.491804, 222.367286, 207.542322, 217.645297, 223.587276, 206.747625, 216.753855, 224.228558, 204.4386, 216.094898, 224.081335, 204.063832, 213.768456, 222.624281, 205.517973, 215.234186, 221.571771, 206.122976, 215.439515, 221.933541, 206.305412, 216.919136, 223.274812, 206.41143
]


x_naive = [
18.21261, 19.972963, 19.20408, 42.635502, 46.589476, 38.861256, 41.880333, 45.969809, 43.075547, 64.953887, 70.603169, 44.412892, 63.149708, 62.586176, 51.801868, 66.046639, 72.02463, 56.020572, 59.072578, 65.486101, 59.412938, 63.534529, 68.875841, 59.341931, 68.774096, 74.478529, 60.624582, 66.531166, 72.411598, 64.260488, 66.65825, 72.356787, 65.997406, 66.020092, 72.29386, 65.553228, 67.369111, 73.799153, 65.657567, 68.403106, 75.1128, 65.516103, 69.795263, 76.711856, 66.166002, 68.738378, 75.371389, 66.824188, 68.313397, 74.906207, 66.55097, 70.170411, 77.15384, 67.039805, 68.64668, 75.344856, 67.288276, 70.344763, 77.494959, 67.495888, 69.716545, 76.598962, 67.67797, 69.060369, 76.06152, 67.849459, 69.99047, 76.793548, 67.992451, 70.01193, 76.982632, 68.219497, 70.053972, 77.375361, 68.000596, 70.057891, 77.367129, 68.22034, 69.092276, 76.131014, 68.53211, 69.74319, 76.822989, 68.480311, 70.298047, 77.276746, 68.571547, 70.6607, 77.672901, 68.783532, 70.209163, 77.503458, 68.919543, 70.649524, 77.736268, 68.988369, 70.438488, 76.613222, 68.397373, 70.407292, 77.634569, 69.059564, 70.518604, 77.551315, 69.031081, 70.629821, 77.638271, 69.189884, 70.435438, 77.55912, 69.2025, 70.732892, 77.520347, 69.403702, 70.593191, 77.736099, 69.364077, 70.661863, 77.651723, 69.484046, 70.720958, 77.674741, 69.492902, 70.622702, 77.642031, 69.296485, 70.948556, 77.974326, 69.703835, 70.819952, 77.860774, 69.715735, 70.94865, 78.040591, 69.778384, 70.84092, 77.968062, 69.754377, 70.920318, 78.056195, 69.896415, 70.969015, 78.059204, 69.852064, 71.013497, 78.004954, 69.864909, 70.897925, 77.899087, 70.018853, 70.94243, 77.912421, 69.837576, 70.911082, 77.339339, 69.776765, 70.506402, 76.99673, 69.898793, 70.679341, 76.501499, 69.785086, 70.251505, 76.867978, 69.602601, 70.366758, 77.372595, 69.945319, 70.702305, 77.53441, 70.049465, 70.446734, 77.198508, 69.650618, 70.445341, 77.148584, 70.051943, 70.727469, 77.467419, 70.017249, 70.697537, 77.604987, 70.096389, 70.612307, 76.982335, 70.014123, 70.918778, 77.404322, 70.468481]

x_best_16 = [
    29.177163, 33.328634, 25.416168, 73.061589, 82.071254, 58.595255, 119.509543, 132.103222, 107.708191, 190.097595, 210.421571, 145.20726, 235.006185, 257.944339, 174.239927, 270.314495, 284.937962, 203.643332, 288.368726, 319.053044, 213.035917, 283.573636, 316.455567, 241.424846, 315.132299, 350.739313, 237.012095, 296.626297, 336.205782, 247.215899, 307.466566, 342.796434, 249.417523, 306.65316, 363.280594, 267.053165, 324.940631, 354.381214, 266.102849, 311.633366, 357.070857, 262.451216, 306.136794, 364.069634, 279.047101, 327.218307, 376.0418, 273.6539, 311.101514, 354.54468, 280.04989, 320.475145, 354.650147, 296.766973, 335.175278, 383.360893, 290.06202, 324.485093, 363.842273, 300.891687, 337.34424, 380.795881, 298.493136, 331.152621, 371.717969, 302.300524, 337.360299, 380.946251, 300.42116, 329.86865, 374.412751, 303.22402, 332.065777, 376.874647, 303.147292, 331.228664, 372.765945, 302.595207, 329.644509, 374.562521, 300.800892, 325.90684, 370.151206, 300.896783, 327.265404, 370.130608, 300.081762, 324.322126, 363.507248, 300.492407, 325.146184, 366.104343, 299.427779, 323.061568, 364.018001, 299.239492, 321.748135, 361.125703, 301.312581, 323.297535, 360.212087, 301.850917, 323.076003, 364.066776, 300.821702, 322.858476, 359.234043, 301.275496, 323.66728, 361.10442, 302.333266, 321.557769, 360.25466, 303.109779, 322.779258, 359.793281, 303.336843, 322.818869, 359.548532, 304.574001, 321.403042, 359.80444, 305.146651, 322.939654, 360.050705, 305.106771, 323.688192, 361.205483, 306.557705, 324.173548, 360.847477, 307.73024, 323.158399, 360.93164, 307.066621, 323.681169, 361.802874, 308.368466, 324.063536, 361.34234, 309.604643, 324.182803, 361.989102, 309.741143, 324.852562, 362.167142, 310.133488, 325.053348, 362.20845, 310.895656, 325.800117, 362.269905, 311.434038, 326.198759, 362.260258, 311.655704, 325.948224, 362.108764, 311.710435, 326.062125, 362.771766, 312.288997, 327.490349, 362.763892, 313.251012, 326.501901, 363.226865, 313.721669, 327.123385, 363.801728, 313.936523, 327.395223, 363.141345, 314.253566, 327.11617, 363.226519, 314.416531, 326.372508, 363.544769, 314.818552, 326.899939, 363.348457, 314.863062, 327.408273, 363.620625, 316.021449, 329.172924, 364.861361, 316.932366
]

x_best_32 = [ 
23.337186, 25.478198, 15.581478, 47.963873, 50.357603, 50.421865, 110.694338, 116.219766, 83.415474, 154.485323, 160.155395, 159.744551, 262.841705, 272.118923, 122.396909, 184.458341, 192.01092, 188.930278, 266.260825, 282.633775, 221.599525, 306.098448, 321.982798, 312.803146, 413.365977, 434.706414, 241.60828, 313.985041, 327.21219, 315.567145, 396.050175, 415.534366, 273.334331, 340.666105, 356.870379, 344.940959, 418.454119, 437.523914, 261.256775, 313.953231, 341.260382, 318.027911, 375.275582, 400.637628, 294.223366, 344.996767, 359.274031, 348.066533, 400.251237, 421.075181, 326.503577, 377.017611, 396.237165, 379.808637, 434.105874, 457.139376, 328.928551, 374.563511, 392.181812, 376.7529, 425.228679, 447.534798, 335.210858, 378.799512, 395.472938, 381.098375, 425.568612, 446.887087, 343.836662, 382.393614, 411.27282, 384.934534, 424.613006, 454.021283, 347.861256, 383.812327, 404.900777, 386.524663, 424.414965, 449.081523, 354.617935, 387.531452, 404.164468, 390.027067, 425.737279, 446.566797, 358.981133, 390.243697, 408.591044, 392.58605, 427.103657, 445.707004, 352.434151, 382.521525, 401.35849, 383.825143, 412.515032, 436.500291, 352.697152, 381.689282, 398.469544, 382.876037, 411.184298, 432.189752, 359.941838, 385.523837, 405.881003, 386.032061, 415.575047, 436.182789, 358.010038, 381.741584, 399.015731, 385.605395, 410.853088, 429.527245, 362.319227, 386.211837, 405.98101, 389.171853, 413.586292, 434.536442, 361.629925, 384.940797, 404.779661, 386.361569, 409.812137, 429.31435, 361.158005, 384.644707, 404.417178, 383.697728, 409.085707, 430.428062, 362.522874, 383.234646, 404.288107, 384.729444, 407.015137, 429.455227, 364.725697, 387.139608, 408.797799, 386.262457, 409.615468, 429.233824, 366.005019, 387.544093, 405.682736, 388.208107, 410.431504, 429.180052, 367.92408, 388.249279, 407.793732, 388.000882, 408.677914, 429.041535, 369.863163, 388.242923, 407.397119, 389.566253, 408.23952, 427.155312, 370.806623, 389.918992, 406.734417, 390.171392, 405.778695, 427.323626, 371.767413, 389.366718, 409.289987, 390.959285, 407.974773, 429.242302, 373.215049, 390.633985, 409.238731, 391.324436, 407.445865, 428.571085, 374.145307, 391.998578, 409.200395, 392.682511, 407.601969, 427.889582, 375.964388
]

x_best_32_no_min = [ 

17.802973, 26.735845, 16.494032, 50.595728, 52.883736, 36.549654, 80.48659, 120.659712, 88.143576, 162.738955, 168.215697, 114.054924, 187.890123, 284.370075, 193.617944, 216.697408, 227.314227, 178.664363, 221.276893, 294.985304, 234.945149, 323.590359, 340.914262, 258.266077, 343.04049, 458.320812, 252.163395, 286.143893, 303.255414, 258.063495, 307.627122, 354.31606, 299.200947, 373.570594, 391.724999, 311.844976, 371.385342, 466.522951, 315.352216, 384.198599, 387.105133, 326.735744, 367.587746, 482.928672, 355.867719, 390.933807, 410.959681, 343.662155, 381.167875, 432.447701, 354.679727, 412.746035, 432.297461, 371.084552, 405.208078, 481.785514, 370.546019, 415.594057, 439.81263, 379.669645, 421.011092, 471.326515, 387.465943, 420.266428, 441.156656, 391.279098, 426.089356, 469.592234, 404.052299, 430.885368, 456.555884, 396.155379, 427.655661, 477.049704, 406.487733, 427.956867, 454.56142, 402.355319, 436.834424, 488.806823, 407.026069, 432.348504, 453.741083, 403.045031, 431.313675, 481.131494, 406.092848, 431.272723, 455.562834, 403.12112, 430.390024, 481.883324, 404.519914, 424.908522, 450.855832, 405.149582, 430.268817, 478.225436, 405.956634, 425.978358, 446.766265, 405.69026, 430.22114, 467.459463, 404.949489, 426.834668, 448.759464, 403.651924, 427.986821, 471.405817, 406.788881, 423.358492, 447.709652, 408.534303, 428.5973, 467.890728, 409.906641, 426.131119, 448.675804, 409.679449, 430.0128, 470.911887, 411.543296, 427.388815, 447.573207, 411.960299, 430.185341, 465.043387, 411.005633, 425.335968, 446.74171, 413.363093, 430.93727, 468.158667, 413.261665, 425.471519, 447.626954, 413.697399, 431.883927, 463.945525, 416.057747, 427.737783, 448.28564, 416.782794, 433.205768, 466.541146, 416.611841, 430.124123, 452.350498, 416.835852, 431.14451, 466.987207, 414.125935, 425.847913, 451.08046, 413.715744, 427.996227, 467.123862, 413.021693, 426.551372, 451.03603, 414.915329, 429.383898, 465.589602, 414.929109, 426.055078, 450.581827, 414.829057, 428.666487, 466.016002, 413.071444, 426.69764, 449.887418, 414.049636, 430.062638, 464.023408, 414.981537, 427.694874, 451.417383, 414.658565, 430.391926, 466.493876, 414.65354, 427.082546, 451.782203, 415.142569, 430.249766, 464.98106, 415.343802
]



x_coalesced = [
34.630118, 36.613774, 28.514933, 87.220262, 90.652296, 48.187664, 102.985208, 109.629127, 88.944643, 163.069501, 172.505966, 102.48849, 167.298467, 177.081416, 115.748606, 174.831383, 186.947281, 127.5823, 184.772187, 195.140789, 126.638154, 174.477489, 183.838675, 144.987329, 191.847944, 201.056128, 146.383681, 188.473571, 199.320364, 149.551942, 187.786519, 199.211951, 155.817757, 189.760672, 199.717826, 158.227484, 192.640062, 203.306472, 162.173847, 195.031341, 204.987723, 166.029639, 197.654545, 208.757837, 167.914567, 197.222431, 208.111835, 169.007492, 196.676458, 207.885732, 172.46806, 201.339972, 211.843918, 172.061873, 197.035324, 208.634597, 175.053961, 199.611277, 210.663085, 175.354457, 198.102414, 208.589889, 174.883863, 195.423517, 205.913794, 175.208883, 194.393588, 205.52753, 173.168389, 193.343769, 204.416929, 173.285842, 192.415492, 203.277347, 173.547018, 191.26759, 202.385336, 173.644724, 190.308136, 202.046537, 174.141592, 190.871172, 201.876308, 175.17873, 191.551943, 201.847747, 175.197396, 190.546949, 200.438472, 175.171531, 190.962545, 200.266347, 175.864243, 190.514414, 200.990382, 176.305633, 191.074215, 200.329375, 176.496104, 190.430686, 200.445136, 177.13947, 190.734363, 200.08137, 177.191629, 190.489131, 200.274082, 177.322024, 190.068958, 199.967393, 177.623085, 190.181114, 200.012347, 177.852454, 190.091788, 199.994271, 178.134225, 190.179527, 200.208275, 178.365005, 190.085437, 199.905514, 178.628797, 188.464754, 197.468608, 178.753579, 189.948192, 199.321297, 179.149612, 190.060994, 199.162388, 179.28826, 190.062396, 199.595118, 179.62731, 190.167336, 200.368522, 179.750661, 190.097753, 199.580487, 179.963887, 189.959919, 199.818039, 179.911253, 189.950691, 199.123677, 180.27631, 189.864952, 199.184017, 180.320798, 189.900297, 198.851881, 180.498296, 189.894181, 198.420318, 180.767732, 189.935811, 195.674399, 180.952593, 189.642961, 197.741081, 180.971003, 189.339613, 198.398494, 181.189869, 189.741555, 198.559402, 181.501118, 190.056976, 198.761528, 181.369958, 189.853562, 199.01846, 181.665917, 189.694732, 198.749531, 181.625398, 189.054736, 198.731721, 181.734351, 189.248206, 198.172943, 181.617015, 189.393939, 196.782049, 182.057531, 189.85255, 198.347457, 182.191317
]

x_C_unroll = [
39.756373, 42.419430, 26.988302, 82.916564, 87.293619, 52.924485, 113.931057, 118.346358, 83.858305, 154.783160, 160.943081, 112.093812, 183.853606, 190.728005, 111.700867, 169.994391, 176.609763, 141.719425, 201.192818, 207.779680, 124.983066, 169.735928, 176.450486, 153.351412, 202.764726, 209.066016, 143.044996, 184.703102, 191.055899, 158.563310, 199.648320, 206.770485, 158.844986, 190.974978, 198.470738, 167.815931, 204.021850, 211.267461, 162.396170, 195.173786, 201.944961, 177.443514, 210.691153, 217.252859, 167.876982, 197.146870, 203.831462, 182.839275, 212.873006, 219.984707, 174.862067, 202.818986, 210.060739, 182.768810, 208.447833, 220.414127, 180.060023, 204.795791, 211.323254, 185.491591, 210.615380, 218.081159, 179.601158, 201.974847, 207.624704, 186.154236, 208.267453, 215.985710, 179.458016, 199.823441, 206.994955, 187.170871, 207.079753, 214.786363, 180.427584, 198.943136, 205.265692, 186.077246, 205.569817, 212.219724, 180.438311, 198.278792, 205.080118, 188.496456, 204.628926, 211.546942, 183.380465, 199.763193, 206.079329, 188.296189, 204.547425, 211.282901, 185.113396, 199.257498, 206.541417, 189.668228, 204.737191, 211.242460, 185.264926, 200.126003, 206.889577, 190.665472, 205.610556, 212.084194, 186.881270, 201.711356, 208.090113, 192.730102, 206.164348, 211.821634, 189.519136, 202.341700, 208.803908, 194.021951, 207.259662, 214.084655, 190.966733, 203.730438, 209.974165, 195.493248, 208.537125, 214.870717, 192.184670, 205.040453, 210.737560, 197.038262, 209.584078, 216.311230, 193.907490, 205.665602, 211.626332, 197.253817, 209.936653, 216.326948, 195.002850, 205.866137, 212.786898, 199.080513, 209.819006, 216.361688, 195.858200, 206.332494, 212.580363, 200.031125, 210.348320, 217.558156, 196.847920, 207.002341, 213.416170, 200.513364, 210.993590, 217.325908, 196.986606, 207.713842, 213.891296, 200.703835, 211.439534, 212.801567, 191.707165, 198.604836, 203.199133, 190.617863, 199.932615, 206.075198, 187.713008, 198.869621, 206.794498, 198.201198, 207.435803, 213.876837, 198.982330, 208.345712, 214.731710, 202.707888, 212.149439, 218.622051, 199.855799, 209.045445, 215.601388, 203.104002, 212.135709, 218.695218, 200.277613, 208.988023, 215.643623, 203.351765, 212.055715, 215.875129, 199.507167, 
]

x_uncoalesced = [
10.072735, 10.60895, 7.58302, 23.52847, 24.363009, 10.187699, 22.668974, 23.339241, 19.007328, 35.476298, 36.397642, 19.893519, 30.810898, 31.313223, 23.141548, 35.492301, 36.194249, 25.438, 37.028121, 37.47673, 24.441619, 33.829048, 34.362154, 27.269013, 36.549479, 37.11998, 27.331835, 35.574537, 36.097917, 27.854929, 35.461651, 36.007531, 29.803616, 36.859045, 36.55475, 29.580022, 36.342501, 36.788532, 30.515226, 37.039155, 37.586162, 31.424088, 37.604769, 38.06612, 31.535906, 37.338629, 37.820766, 31.618769, 37.105047, 37.559554, 32.576281, 37.874306, 38.32979, 32.204052, 37.169636, 37.666937, 33.197653, 38.031346, 38.534362, 33.143462, 37.776189, 38.211649, 33.092253, 37.488368, 37.953666, 33.449303, 37.406118, 38.054632, 33.886104, 37.996662, 38.399923, 34.095232, 38.014673, 38.460974, 34.215747, 38.001899, 38.520289, 34.18105, 37.777678, 38.176125, 34.355594, 37.874748, 38.3461, 34.521559, 37.924183, 38.394634, 34.643802, 37.960182, 38.441301, 34.762623, 37.980052, 38.437387, 34.866762, 37.971938, 38.394191, 34.958469, 38.04767, 38.444421, 35.052699, 38.01773, 38.441672, 35.120931, 37.984476, 38.470418, 35.183936, 37.969042, 38.392435, 35.359588, 38.08969, 38.471877, 35.424326, 38.077024, 38.491056, 35.508953, 38.113254, 38.477153, 35.490649, 38.015928, 38.461595, 35.600651, 38.031259, 38.440929, 35.67438, 38.086496, 38.486234, 35.762342, 38.130148, 38.491124, 35.76187, 38.068452, 38.469739, 35.847071, 38.10915, 38.466299, 35.926978, 38.145219, 38.487078, 35.974733, 38.155216, 38.514222, 35.978496, 38.099574, 38.471659, 36.009095, 38.087342, 38.449079, 36.121975, 38.170544, 38.48528, 36.153642, 38.164545, 38.49233, 36.196942, 38.166116, 38.479594, 36.183506, 38.116489, 38.479656, 36.229673, 38.148349, 38.474755, 36.298646, 38.164412, 38.482503, 36.330052, 38.159423, 38.47674, 36.343503, 38.143744, 38.477283, 36.380136, 38.155163, 38.45813, 36.435071, 38.18089, 38.484443, 36.453946, 38.164893, 38.477921, 36.466198, 38.14692, 38.47814, 36.472734, 38.139969, 38.445886, 36.515453, 38.13987, 38.461557, 36.552029
               ]


data = {"cuda-best (32x32 Thread Blocks/Tiles; Constant Block Size, 4 elements)": x_best_32_no_min,
"cuda-best (32x32 Thread Blocks/Tiles; 4 elements)": x_best_32,
"cuda-best (16x16 Thread Blocks/Tiles; 4 elements)": x_best_16,
"cuda-best (8x8 Thread Blocks/Tiles; 4 elements)": x_best_8,
"cuda-interleaved __syncthreads (32x32 Thread Blocks/Tiles; 1 element)": x_interleave_sync,
"cuda-C unrolled (x2 steps) (32x32 Thread Blocks/Tiles; 1 element)": x_C_unroll,
"cuda-coalesced shared memory (32x32 Thread Blocks/Tiles; 1 element)": x_coalesced,
"cuda-naive": x_naive,
"cuda-uncoalesced shared memory (32x32 Thread Blocks/Tiles; 1 element)": x_uncoalesced,
"blas-multicore": x_blas}

tuples = [(key, data[key]) for key in data]
data = OrderedDict(tuples)


df = pd.DataFrame(data, index = y)
df.index.rename('N', inplace=True)


writer = pd.ExcelWriter('FullPerformanceExperiment.Data.xlsx')
df.to_excel(writer, 'Sheet1')
writer.save()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import ScalarFormatter

# plt.rcParams['figure.figsize'] = (9, 6)
# plt.rcParams['figure.dpi'] = 160
# plt.rcParams['figure.facecolor'] = 'w'
# plt.rcParams['figure.edgecolor'] = 'k'
# ax = plt.subplot(111)
plt.figure(num=None, figsize=(9, 6), dpi=160, facecolor='w', edgecolor='k')
plt.xlabel('Flops/Byte')
plt.ylabel('Gflops/sec')

x_ticks = [1/16, 1/8, 1/4, 1/2, 1, 2, 4, 8, 16, 32, 64, 128, 256]
x_ticks_show = [1/16, 1/4, 1, 4, 16,  64, 256]
y_ticks = [8, 16, 32, 64, 128, 256, 512, 1024, 2048,]
y_ticks_show = [8, 16, 32, 64, 128, 256, 512, 1024, 2048,]

x_ticks = [1/16, 1/8, 1/4, 1/2, 1, 2, 4, 8, 16, 32, 64, 128, 256]

bw_line = [min(i*256, 1370) for i in x_ticks]




# plt.semilogx(y, x_no_unroll, label="dgemm-blocked (No Loop Unrolling)")
plt.loglog(x_ticks,bw_line,  label="GK210")
# plt.vlines([15.6], min(x_ticks_show), [473], linestyle="dashed", label="Q = 15.6")
plt.vlines([2], min(x_ticks_show), [473], linestyle="dashed", label="Q = 2")
# plt.vlines([0.25], min(x_ticks_show), [473], linestyle="dashed", label="Q = 15.6")


plt.vlines([0.12], min(x_ticks_show), [30], linestyle="dashed", label="Q = 0.125")
plt.hlines([473], 473, 1.85, linestyle="solid", label="473 Gflops/s(achieved)")
# plt.hlines([473], 473, 0.1, linestyle="solid", label="473 Gflops/s(achieved)")


plt.loglog(basex=2, basey=2)

plt.axis([0, max(x_ticks), min(y_ticks_show), max(y_ticks_show)])
plt.grid(True)
plt.xticks(x_ticks)
plt.yticks(y_ticks_show)



ax = plt.gca()
ax.text(0.125, 320, u'Peak Memory Bandwidth (240 GB/s)',  rotation=45)
ax.text(8, 1450, u'Peak Performance (1.37 Tflop/s)',  rotation=0)
# ax.text(12.6, 20, u'CUDA-Best',  rotation=90)
ax.text(0.0999, 20, u'CUDA-Naive',  rotation=90)
ax.text(1.6, 20, u'CUDA-Best',  rotation=90)
# ax.text(.2, 20, u'CUDA-Best',  rotation=90)



for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)

plt.show()
# plt.savefig('240GbRoofline.png', bbox_inches='tight')

# %%
import pandas as pd
from collections import OrderedDict
from collections import defaultdict

x_ticks = [1/16, 1/8, 1/4, 1/2, 1, 2, 4, 8, 16, 32, 64, 128, 256]
y_ticks_show = [8, 16, 32, 64, 128, 256, 512, 1024, 2048,]

bw_line = [min(i*240, 1370) for i in x_ticks]
cbest = defaultdict(int)
for x in x_ticks:
    if x == 2:
        val = 481
    else:
        val = "N/A"
    cbest[x]= val

    naive = defaultdict(int)
for x in x_ticks:
    if x == 1/8:
        val = "30 (Predicted)"
    else:
        val = "N/A"
    naive[x]= val
    
        
tuples = [("CUDA-Best (Gflops/s)",cbest), 
          ("CUDA-Naive (Gflops/s)", naive),
         ("Roofline Max (Gflops/s; Predicted) ", bw_line)]
data = OrderedDict(tuples)


df = pd.DataFrame(data, index = x_ticks)
# df.columns.name = "Q"
df.index.rename('Q', inplace=True)


writer = pd.ExcelWriter('Roofline_240GB.Data.xlsx')
df.to_excel(writer, 'Sheet1')
writer.save()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import ScalarFormatter

# plt.rcParams['figure.figsize'] = (9, 6)
# plt.rcParams['figure.dpi'] = 160
# plt.rcParams['figure.facecolor'] = 'w'
# plt.rcParams['figure.edgecolor'] = 'k'
# ax = plt.subplot(111)
plt.figure(num=None, figsize=(9, 6), dpi=160, facecolor='w', edgecolor='k')
plt.xlabel('Flops/Byte')
plt.ylabel('Gflops/sec')

x_ticks = [1/16, 1/8, 1/4, 1/2, 1, 2, 4, 8, 16, 32, 64, 128, 256]
x_ticks_show = [1/16, 1/4, 1, 4, 16,  64, 256]
y_ticks = [8, 16, 32, 64, 128, 256, 512, 1024, 2048,]
y_ticks_show = [8, 16, 32, 64, 128, 256, 512, 1024, 2048,]


bw_line = [min(i*154, 1370) for i in x_ticks]



# plt.semilogx(y, x_no_unroll, label="dgemm-blocked (No Loop Unrolling)")
plt.loglog(x_ticks,bw_line,  label="GK210")
# plt.vlines([15.6], min(x_ticks_show), [473], linestyle="dashed", label="Q = 15.6")
plt.vlines([3], min(x_ticks_show), [473], linestyle="dashed", label="Q = 3")
# plt.vlines([0.25], min(x_ticks_show), [473], linestyle="dashed", label="Q = 15.6")


plt.vlines([0.12], min(x_ticks_show), [18], linestyle="dashed", label="Q = 0.125")
plt.hlines([473], 473, 3, linestyle="solid", label="473 Gflops/s(achieved)")
# plt.hlines([473], 473, 0.1, linestyle="solid", label="473 Gflops/s(achieved)")


# plt.loglog([15.73],[473],  label="dpoint")

plt.loglog(basex=2, basey=2)

plt.axis([0, max(x_ticks), min(y_ticks_show), max(y_ticks_show)])
plt.grid(True)
plt.xticks(x_ticks)
plt.yticks(y_ticks_show)



ax = plt.gca()
ax.text(0.125, 200, u'Peak Memory Bandwidth (154 GB/s)',  rotation=45)
ax.text(8, 1450, u'Peak Performance (1.37 Tflop/s)',  rotation=0)
# ax.text(12.6, 20, u'CUDA-Best',  rotation=90)
ax.text(0.0999, 20, u'CUDA-Naive',  rotation=90)
ax.text(2.4, 19, u'CUDA-Best',  rotation=90)
# ax.text(.2, 20, u'CUDA-Best',  rotation=90)



for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)

# plt.show()
plt.savefig('154GbRoofline.png', bbox_inches='tight')

# %%
import pandas as pd
from collections import OrderedDict
from collections import defaultdict

x_ticks = [1/16, 1/8, 1/4, 1/2, 1, 2, 3.125, 4, 8, 16, 32, 64, 128, 256]
y_ticks_show = [8, 16, 32, 64, 128, 256, 512, 1024, 2048,]

bw_line = [min(i*154, 1370) for i in x_ticks]
cbest = defaultdict(int)
for x in x_ticks:
    if x == 3.125:
        val = 481
    else:
        val = "N/A"
    cbest[x]= val

    naive = defaultdict(int)
for x in x_ticks:
    if x == 1/8:
        val = "30 (Predicted)"
    else:
        val = "N/A"
    naive[x]= val
    
        
tuples = [("CUDA-Best (Gflops/s)",cbest), 
          ("CUDA-Naive (Gflops/s)", naive),
         ("Roofline Max (Gflops/s; Predicted) ", bw_line)]
data = OrderedDict(tuples)


df = pd.DataFrame(data, index = x_ticks)
# df.columns.name = "Q"
df.index.rename('Q', inplace=True)


writer = pd.ExcelWriter('Roofline_154GB.Data.xlsx')
df.to_excel(writer, 'Sheet1')
writer.save()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# plt.rcParams['figure.figsize'] = (9, 6)
# plt.rcParams['figure.dpi'] = 160
# plt.rcParams['figure.facecolor'] = 'w'
# plt.rcParams['figure.edgecolor'] = 'k'
# ax = plt.subplot(111)
plt.figure(num=None, figsize=(9, 6), dpi=160, facecolor='w', edgecolor='k')
plt.xlabel('Square Matrix Dimension N')
plt.ylabel('GPU Throughput/CPU Throughput')


y = [
256, 
     
512, 
     
 
768, 
     
1023, 
1024, 
1025, 
     
2047, 
2048, 
2049, 
]

x_blas = [

    5.84,

17.4,
 
 45.3,
    
73.7,
73.6,
73.5,
    
171,
182,
175,]





x_best_32_no_min = [ 
                    
296.258264, 
                    
485.178298, 
                    
 
475.302723, 
                    
462.404875, 
484.237978, 
387.648832, 
                    
449.923177, 
469.690363, 
414.559485, ]

ratio = []
for i in range (len(y)):
    ratio.append(x_best_32_no_min[i]/x_blas[i]
                )


plt.semilogx(y, ratio,marker='o', label="cuda-best/blas multicore Gflops/s ratio")

# plt.semilogx(y, x_blas, label="blas-multicore")
plt.semilogx(basex=2)

plt.axis([min(y), max(y), 0, max(ratio)])
plt.grid(True)
plt.xticks([256,  512, 1024, 2048])
ax = plt.gca()
for axis in [ax.xaxis]:
    axis.set_major_formatter(ScalarFormatter())
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)
# plt.show()
plt.savefig('speedupRatio.png', bbox_inches='tight')

# %%
import pandas as pd
from collections import OrderedDict


y = [
256, 
512, 
768, 
1023, 
1024, 
1025, 
2047, 
2048, 
2049, 
]

x_blas = [
    5.84,
17.4,
 45.3,
73.7,
73.6,
73.5, 
171,
182,
175,]

x_best_32_no_min = [         
296.258264,         
485.178298, 
475.302723,         
462.404875, 
484.237978, 
387.648832,         
449.923177, 
469.690363, 
414.559485, ]

ratio = []
for i in range (len(y)):
    ratio.append(x_best_32_no_min[i]/x_blas[i]
                )
    
tuples = [("cuda-best/blas multicore Gflops/s ratio",ratio), 
          ("cuda-best (32x32 Thread Blocks/Tiles; Constant Block Size, 4 elements)(Gflops/s)", x_best_32_no_min),
         ("blas-multicore (Gflops/s)", x_blas)]
data = OrderedDict(tuples)


df = pd.DataFrame(data, index = y)
df.index.rename('N', inplace=True)

writer = pd.ExcelWriter('Speedup.Data.xlsx')
df.to_excel(writer, 'Sheet1')
writer.save()
